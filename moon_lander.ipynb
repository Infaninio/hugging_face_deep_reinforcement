# %%
from pyvirtualdisplay import Display

virtual_display = Display(visible=False, size=(1400, 900))
virtual_display.start()

# %%
import gym

from huggingface_sb3 import load_from_hub, package_to_hub, push_to_hub
from huggingface_hub import notebook_login # To log to our Hugging Face account to be able to upload models to the Hub.

from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_vec_env

# %%
import gym

# First, we create our environment called LunarLander-v2
env = gym.make("LunarLander-v2")

# Then we reset this environment
observation = env.reset()

for _ in range(20):
  # Take a random action
  action = env.action_space.sample()
  print("Action taken:", action)

  # Do this action in the environment and get
  # next_state, reward, done and info
  observation, reward, done, info = env.step(action)
  
  # If the game is done (in our case we land, crashed or timeout)
  if done:
      # Reset the environment
      print("Environment is reset")
      observation = env.reset()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 4
#       1 import gym
#       3 # First, we create our environment called LunarLander-v2
# ----> 4 env = gym.make("LunarLander-v2")
#       6 # Then we reset this environment
#       7 observation = env.reset()
#
# File ~/dev/hugging_face_deep_reinforcement/.venv/lib/python3.8/site-packages/gym/envs/registration.py:235, in make(id, **kwargs)
#     234 def make(id, **kwargs):
# --> 235     return registry.make(id, **kwargs)
#
# File ~/dev/hugging_face_deep_reinforcement/.venv/lib/python3.8/site-packages/gym/envs/registration.py:129, in EnvRegistry.make(self, path, **kwargs)
#     127     logger.info("Making new env: %s", path)
#     128 spec = self.spec(path)
# --> 129 env = spec.make(**kwargs)
#     130 return env
#
# File ~/dev/hugging_face_deep_reinforcement/.venv/lib/python3.8/site-packages/gym/envs/registration.py:89, in EnvSpec.make(self, **kwargs)
#      87     env = self.entry_point(**_kwargs)
#      88 else:
# ---> 89     cls = load(self.entry_point)
#      90     env = cls(**_kwargs)
#      92 # Make the environment aware of which spec it came from.
#
# File ~/dev/hugging_face_deep_reinforcement/.venv/lib/python3.8/site-packages/gym/envs/registration.py:28, in load(name)
#      26 mod_name, attr_name = name.split(":")
#      27 mod = importlib.import_module(mod_name)
# ---> 28 fn = getattr(mod, attr_name)
#      29 return fn
#
# AttributeError: module 'gym.envs.box2d' has no attribute 'LunarLander'

# %%
# We create our environment with gym.make("")
env = gym.make("LunarLander-v2")
env.reset()
print("_____OBSERVATION SPACE_____ \n")
print("Observation Space Shape", env.observation_space.shape)
print("Sample observation", env.observation_space.sample()) # Get a random observation

print("\n _____ACTION SPACE_____ \n")
print("Action Space Shape", env.action_space.n)
print("Action Space Sample", env.action_space.sample()) # Take a random action
# Out:
# _____OBSERVATION SPACE_____
#
# Observation Space Shape (8,)
# Sample observation [-0.10979602 -0.09774535 -0.48209837  1.2147962   0.4279852   2.4926512
#   0.13152549 -0.20819116]
#
#  _____ACTION SPACE_____
#
# Action Space Shape 4
# Action Space Sample 0

# %%
# We added some parameters to accelerate the training
model = PPO(
    policy = 'MlpPolicy',
    env = env,
    n_steps = 1024,
    batch_size = 256,
    n_epochs = 4,
    gamma = 0.999,
    gae_lambda = 0.98,
    ent_coef = 0.01,
    verbose=1)

model.learn(total_timesteps=1000000)
model_name = "ppo-LunarLander-v2"
model.save(model_name)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 85.3     |
# |    ep_rew_mean     | -193     |
# | time/              |          |
# |    fps             | 824      |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1024     |
# ---------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 84.7          |
# |    ep_rew_mean          | -167          |
# | time/                   |               |
# |    fps                  | 1024          |
# |    iterations           | 2             |
# |    time_elapsed         | 1             |
# |    total_timesteps      | 2048          |
# | train/                  |               |
# |    approx_kl            | 9.4370975e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.39         |
# |    explained_variance   | -0.00324      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.91e+03      |
# |    n_updates            | 4             |
# |    policy_gradient_loss | -0.000765     |
# |    value_loss           | 7.44e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 87.3         |
# |    ep_rew_mean          | -158         |
# | time/                   |              |
# |    fps                  | 1113         |
# |    iterations           | 3            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 3072         |
# | train/                  |              |
# |    approx_kl            | 6.441469e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | -0.00375     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.01e+03     |
# |    n_updates            | 8            |
# |    policy_gradient_loss | -0.000477    |
# |    value_loss           | 3.97e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 87.5          |
# |    ep_rew_mean          | -164          |
# | time/                   |               |
# |    fps                  | 1170          |
# |    iterations           | 4             |
# |    time_elapsed         | 3             |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 0.00010592915 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.39         |
# |    explained_variance   | -0.00665      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.38e+03      |
# |    n_updates            | 12            |
# |    policy_gradient_loss | -0.000782     |
# |    value_loss           | 4.27e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 89.6         |
# |    ep_rew_mean          | -169         |
# | time/                   |              |
# |    fps                  | 1202         |
# |    iterations           | 5            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 5120         |
# | train/                  |              |
# |    approx_kl            | 8.588901e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | -0.00634     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.18e+03     |
# |    n_updates            | 16           |
# |    policy_gradient_loss | -0.000686    |
# |    value_loss           | 6.39e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 91           |
# |    ep_rew_mean          | -166         |
# | time/                   |              |
# |    fps                  | 1224         |
# |    iterations           | 6            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 8.301949e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.00578     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.73e+03     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.000225    |
# |    value_loss           | 6.71e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 91.2          |
# |    ep_rew_mean          | -164          |
# | time/                   |               |
# |    fps                  | 1246          |
# |    iterations           | 7             |
# |    time_elapsed         | 5             |
# |    total_timesteps      | 7168          |
# | train/                  |               |
# |    approx_kl            | 3.5738805e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | -0.0074       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.78e+03      |
# |    n_updates            | 24            |
# |    policy_gradient_loss | -0.000369     |
# |    value_loss           | 3.78e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 91.1         |
# |    ep_rew_mean          | -166         |
# | time/                   |              |
# |    fps                  | 1246         |
# |    iterations           | 8            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 3.995141e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.0171      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.62e+03     |
# |    n_updates            | 28           |
# |    policy_gradient_loss | -0.000283    |
# |    value_loss           | 6.17e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 91.6          |
# |    ep_rew_mean          | -168          |
# | time/                   |               |
# |    fps                  | 1256          |
# |    iterations           | 9             |
# |    time_elapsed         | 7             |
# |    total_timesteps      | 9216          |
# | train/                  |               |
# |    approx_kl            | 2.0343286e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | -0.00881      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.57e+03      |
# |    n_updates            | 32            |
# |    policy_gradient_loss | -0.000168     |
# |    value_loss           | 5.93e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 92.2         |
# |    ep_rew_mean          | -165         |
# | time/                   |              |
# |    fps                  | 1268         |
# |    iterations           | 10           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 2.477091e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.00222     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.78e+03     |
# |    n_updates            | 36           |
# |    policy_gradient_loss | -0.000226    |
# |    value_loss           | 5.93e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 94            |
# |    ep_rew_mean          | -166          |
# | time/                   |               |
# |    fps                  | 1277          |
# |    iterations           | 11            |
# |    time_elapsed         | 8             |
# |    total_timesteps      | 11264         |
# | train/                  |               |
# |    approx_kl            | 3.9644714e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | -0.00841      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.57e+03      |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.000388     |
# |    value_loss           | 4.79e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 94.2          |
# |    ep_rew_mean          | -173          |
# | time/                   |               |
# |    fps                  | 1284          |
# |    iterations           | 12            |
# |    time_elapsed         | 9             |
# |    total_timesteps      | 12288         |
# | train/                  |               |
# |    approx_kl            | 2.2764842e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | -0.0153       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.46e+03      |
# |    n_updates            | 44            |
# |    policy_gradient_loss | -0.000234     |
# |    value_loss           | 5.96e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 95.5          |
# |    ep_rew_mean          | -170          |
# | time/                   |               |
# |    fps                  | 1289          |
# |    iterations           | 13            |
# |    time_elapsed         | 10            |
# |    total_timesteps      | 13312         |
# | train/                  |               |
# |    approx_kl            | 2.7051894e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | -0.00894      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.69e+03      |
# |    n_updates            | 48            |
# |    policy_gradient_loss | -0.000454     |
# |    value_loss           | 5.6e+03       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 95.7         |
# |    ep_rew_mean          | -165         |
# | time/                   |              |
# |    fps                  | 1293         |
# |    iterations           | 14           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 5.648122e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.0029      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.82e+03     |
# |    n_updates            | 52           |
# |    policy_gradient_loss | -0.000635    |
# |    value_loss           | 3.57e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 96            |
# |    ep_rew_mean          | -165          |
# | time/                   |               |
# |    fps                  | 1297          |
# |    iterations           | 15            |
# |    time_elapsed         | 11            |
# |    total_timesteps      | 15360         |
# | train/                  |               |
# |    approx_kl            | 8.0347585e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | -0.011        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.71e+03      |
# |    n_updates            | 56            |
# |    policy_gradient_loss | -0.000403     |
# |    value_loss           | 3.16e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 94.4          |
# |    ep_rew_mean          | -159          |
# | time/                   |               |
# |    fps                  | 1301          |
# |    iterations           | 16            |
# |    time_elapsed         | 12            |
# |    total_timesteps      | 16384         |
# | train/                  |               |
# |    approx_kl            | 5.2179792e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | -0.0203       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.81e+03      |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -0.00031      |
# |    value_loss           | 3.68e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 95.5          |
# |    ep_rew_mean          | -160          |
# | time/                   |               |
# |    fps                  | 1303          |
# |    iterations           | 17            |
# |    time_elapsed         | 13            |
# |    total_timesteps      | 17408         |
# | train/                  |               |
# |    approx_kl            | 4.9162132e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | -0.0263       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.72e+03      |
# |    n_updates            | 64            |
# |    policy_gradient_loss | -0.000458     |
# |    value_loss           | 3.76e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 96.9         |
# |    ep_rew_mean          | -152         |
# | time/                   |              |
# |    fps                  | 1292         |
# |    iterations           | 18           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 3.208767e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.0174      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.76e+03     |
# |    n_updates            | 68           |
# |    policy_gradient_loss | -0.000885    |
# |    value_loss           | 5.83e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 96.1         |
# |    ep_rew_mean          | -149         |
# | time/                   |              |
# |    fps                  | 1291         |
# |    iterations           | 19           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 19456        |
# | train/                  |              |
# |    approx_kl            | 6.537291e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.00992     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 862          |
# |    n_updates            | 72           |
# |    policy_gradient_loss | -0.000503    |
# |    value_loss           | 1.9e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 96.1         |
# |    ep_rew_mean          | -148         |
# | time/                   |              |
# |    fps                  | 1294         |
# |    iterations           | 20           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 8.575432e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.0344      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.3e+03      |
# |    n_updates            | 76           |
# |    policy_gradient_loss | -0.000459    |
# |    value_loss           | 4.52e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 96.7          |
# |    ep_rew_mean          | -149          |
# | time/                   |               |
# |    fps                  | 1299          |
# |    iterations           | 21            |
# |    time_elapsed         | 16            |
# |    total_timesteps      | 21504         |
# | train/                  |               |
# |    approx_kl            | 2.3966364e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | -0.0316       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.56e+03      |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -0.000216     |
# |    value_loss           | 5.2e+03       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 98.3          |
# |    ep_rew_mean          | -148          |
# | time/                   |               |
# |    fps                  | 1303          |
# |    iterations           | 22            |
# |    time_elapsed         | 17            |
# |    total_timesteps      | 22528         |
# | train/                  |               |
# |    approx_kl            | 4.9809925e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | -0.00696      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.48e+03      |
# |    n_updates            | 84            |
# |    policy_gradient_loss | -0.000368     |
# |    value_loss           | 3.2e+03       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 97.9          |
# |    ep_rew_mean          | -146          |
# | time/                   |               |
# |    fps                  | 1307          |
# |    iterations           | 23            |
# |    time_elapsed         | 18            |
# |    total_timesteps      | 23552         |
# | train/                  |               |
# |    approx_kl            | 5.6143268e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | -0.0187       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.46e+03      |
# |    n_updates            | 88            |
# |    policy_gradient_loss | -0.000352     |
# |    value_loss           | 3.16e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 96.6         |
# |    ep_rew_mean          | -142         |
# | time/                   |              |
# |    fps                  | 1311         |
# |    iterations           | 24           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 3.620563e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.00759     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.52e+03     |
# |    n_updates            | 92           |
# |    policy_gradient_loss | -0.000273    |
# |    value_loss           | 3.09e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 96.6          |
# |    ep_rew_mean          | -147          |
# | time/                   |               |
# |    fps                  | 1314          |
# |    iterations           | 25            |
# |    time_elapsed         | 19            |
# |    total_timesteps      | 25600         |
# | train/                  |               |
# |    approx_kl            | 4.1974883e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | -0.00936      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.04e+03      |
# |    n_updates            | 96            |
# |    policy_gradient_loss | -0.000437     |
# |    value_loss           | 2.04e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 97            |
# |    ep_rew_mean          | -139          |
# | time/                   |               |
# |    fps                  | 1317          |
# |    iterations           | 26            |
# |    time_elapsed         | 20            |
# |    total_timesteps      | 26624         |
# | train/                  |               |
# |    approx_kl            | 0.00010417687 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | -0.0278       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.23e+03      |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -0.000784     |
# |    value_loss           | 4.57e+03      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 94          |
# |    ep_rew_mean          | -142        |
# | time/                   |             |
# |    fps                  | 1320        |
# |    iterations           | 27          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 27648       |
# | train/                  |             |
# |    approx_kl            | 8.71091e-05 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -0.00567    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.08e+03    |
# |    n_updates            | 104         |
# |    policy_gradient_loss | -0.000531   |
# |    value_loss           | 2.33e+03    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 94.4          |
# |    ep_rew_mean          | -141          |
# | time/                   |               |
# |    fps                  | 1323          |
# |    iterations           | 28            |
# |    time_elapsed         | 21            |
# |    total_timesteps      | 28672         |
# | train/                  |               |
# |    approx_kl            | 2.2316352e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | -0.00189      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.08e+03      |
# |    n_updates            | 108           |
# |    policy_gradient_loss | -0.000224     |
# |    value_loss           | 4.15e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 93.8          |
# |    ep_rew_mean          | -135          |
# | time/                   |               |
# |    fps                  | 1326          |
# |    iterations           | 29            |
# |    time_elapsed         | 22            |
# |    total_timesteps      | 29696         |
# | train/                  |               |
# |    approx_kl            | 1.4754944e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | -0.0095       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.41e+03      |
# |    n_updates            | 112           |
# |    policy_gradient_loss | -0.000294     |
# |    value_loss           | 2.77e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 93.7          |
# |    ep_rew_mean          | -134          |
# | time/                   |               |
# |    fps                  | 1329          |
# |    iterations           | 30            |
# |    time_elapsed         | 23            |
# |    total_timesteps      | 30720         |
# | train/                  |               |
# |    approx_kl            | 4.3107604e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | -0.00381      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.5e+03       |
# |    n_updates            | 116           |
# |    policy_gradient_loss | -0.000212     |
# |    value_loss           | 2.78e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 91.4         |
# |    ep_rew_mean          | -132         |
# | time/                   |              |
# |    fps                  | 1332         |
# |    iterations           | 31           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 31744        |
# | train/                  |              |
# |    approx_kl            | 3.771542e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -0.00339     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.06e+03     |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.000311    |
# |    value_loss           | 2.08e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90.5         |
# |    ep_rew_mean          | -131         |
# | time/                   |              |
# |    fps                  | 1335         |
# |    iterations           | 32           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 4.358421e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -0.0136      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.57e+03     |
# |    n_updates            | 124          |
# |    policy_gradient_loss | -0.000535    |
# |    value_loss           | 2.87e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 91.4          |
# |    ep_rew_mean          | -138          |
# | time/                   |               |
# |    fps                  | 1337          |
# |    iterations           | 33            |
# |    time_elapsed         | 25            |
# |    total_timesteps      | 33792         |
# | train/                  |               |
# |    approx_kl            | 1.4307152e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | -0.00626      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.44e+03      |
# |    n_updates            | 128           |
# |    policy_gradient_loss | -2.53e-05     |
# |    value_loss           | 2.89e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 90.7          |
# |    ep_rew_mean          | -136          |
# | time/                   |               |
# |    fps                  | 1340          |
# |    iterations           | 34            |
# |    time_elapsed         | 25            |
# |    total_timesteps      | 34816         |
# | train/                  |               |
# |    approx_kl            | 5.9042708e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | -0.00981      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.43e+03      |
# |    n_updates            | 132           |
# |    policy_gradient_loss | -0.000541     |
# |    value_loss           | 4.89e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 91.1          |
# |    ep_rew_mean          | -134          |
# | time/                   |               |
# |    fps                  | 1343          |
# |    iterations           | 35            |
# |    time_elapsed         | 26            |
# |    total_timesteps      | 35840         |
# | train/                  |               |
# |    approx_kl            | 3.5029952e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | -0.016        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.45e+03      |
# |    n_updates            | 136           |
# |    policy_gradient_loss | -7.24e-05     |
# |    value_loss           | 3.25e+03      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 92.8        |
# |    ep_rew_mean          | -138        |
# | time/                   |             |
# |    fps                  | 1345        |
# |    iterations           | 36          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 9.48566e-05 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -0.0103     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 748         |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.000605   |
# |    value_loss           | 1.5e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 93.1        |
# |    ep_rew_mean          | -141        |
# | time/                   |             |
# |    fps                  | 1347        |
# |    iterations           | 37          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 37888       |
# | train/                  |             |
# |    approx_kl            | 0.000256692 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -0.00232    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.53e+03    |
# |    n_updates            | 144         |
# |    policy_gradient_loss | -0.00107    |
# |    value_loss           | 3.02e+03    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 92.8          |
# |    ep_rew_mean          | -138          |
# | time/                   |               |
# |    fps                  | 1349          |
# |    iterations           | 38            |
# |    time_elapsed         | 28            |
# |    total_timesteps      | 38912         |
# | train/                  |               |
# |    approx_kl            | 0.00041622738 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | -0.00034      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.51e+03      |
# |    n_updates            | 148           |
# |    policy_gradient_loss | -0.00232      |
# |    value_loss           | 5.3e+03       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 91.2          |
# |    ep_rew_mean          | -136          |
# | time/                   |               |
# |    fps                  | 1351          |
# |    iterations           | 39            |
# |    time_elapsed         | 29            |
# |    total_timesteps      | 39936         |
# | train/                  |               |
# |    approx_kl            | 0.00014068477 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | -0.00412      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 930           |
# |    n_updates            | 152           |
# |    policy_gradient_loss | -0.00056      |
# |    value_loss           | 1.85e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90.7         |
# |    ep_rew_mean          | -133         |
# | time/                   |              |
# |    fps                  | 1353         |
# |    iterations           | 40           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 5.677849e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -0.024       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.19e+03     |
# |    n_updates            | 156          |
# |    policy_gradient_loss | -0.000193    |
# |    value_loss           | 2.5e+03      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 92.2          |
# |    ep_rew_mean          | -129          |
# | time/                   |               |
# |    fps                  | 1354          |
# |    iterations           | 41            |
# |    time_elapsed         | 30            |
# |    total_timesteps      | 41984         |
# | train/                  |               |
# |    approx_kl            | 0.00021137518 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | -0.00869      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.23e+03      |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -0.00123      |
# |    value_loss           | 2.34e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 92.8          |
# |    ep_rew_mean          | -124          |
# | time/                   |               |
# |    fps                  | 1355          |
# |    iterations           | 42            |
# |    time_elapsed         | 31            |
# |    total_timesteps      | 43008         |
# | train/                  |               |
# |    approx_kl            | 0.00032637134 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | -0.00324      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 679           |
# |    n_updates            | 164           |
# |    policy_gradient_loss | -0.000812     |
# |    value_loss           | 1.43e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 94.3          |
# |    ep_rew_mean          | -122          |
# | time/                   |               |
# |    fps                  | 1356          |
# |    iterations           | 43            |
# |    time_elapsed         | 32            |
# |    total_timesteps      | 44032         |
# | train/                  |               |
# |    approx_kl            | 0.00012082694 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.36         |
# |    explained_variance   | -0.00241      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 804           |
# |    n_updates            | 168           |
# |    policy_gradient_loss | -0.000623     |
# |    value_loss           | 1.82e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 96.3          |
# |    ep_rew_mean          | -122          |
# | time/                   |               |
# |    fps                  | 1357          |
# |    iterations           | 44            |
# |    time_elapsed         | 33            |
# |    total_timesteps      | 45056         |
# | train/                  |               |
# |    approx_kl            | 0.00014674629 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.36         |
# |    explained_variance   | -0.0041       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 778           |
# |    n_updates            | 172           |
# |    policy_gradient_loss | -0.000573     |
# |    value_loss           | 1.58e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 97.1         |
# |    ep_rew_mean          | -122         |
# | time/                   |              |
# |    fps                  | 1358         |
# |    iterations           | 45           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 46080        |
# | train/                  |              |
# |    approx_kl            | 8.920359e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -0.00206     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 553          |
# |    n_updates            | 176          |
# |    policy_gradient_loss | -0.000323    |
# |    value_loss           | 1.21e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 98.9          |
# |    ep_rew_mean          | -122          |
# | time/                   |               |
# |    fps                  | 1360          |
# |    iterations           | 46            |
# |    time_elapsed         | 34            |
# |    total_timesteps      | 47104         |
# | train/                  |               |
# |    approx_kl            | 3.1535223e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.36         |
# |    explained_variance   | -0.0146       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.15e+03      |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -0.000172     |
# |    value_loss           | 2.55e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 99.7          |
# |    ep_rew_mean          | -118          |
# | time/                   |               |
# |    fps                  | 1361          |
# |    iterations           | 47            |
# |    time_elapsed         | 35            |
# |    total_timesteps      | 48128         |
# | train/                  |               |
# |    approx_kl            | 0.00047582696 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | -0.00174      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.02e+03      |
# |    n_updates            | 184           |
# |    policy_gradient_loss | -0.00178      |
# |    value_loss           | 2.28e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 101          |
# |    ep_rew_mean          | -118         |
# | time/                   |              |
# |    fps                  | 1362         |
# |    iterations           | 48           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 8.135667e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | -0.00723     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.2e+03      |
# |    n_updates            | 188          |
# |    policy_gradient_loss | -0.000222    |
# |    value_loss           | 2.14e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 102          |
# |    ep_rew_mean          | -116         |
# | time/                   |              |
# |    fps                  | 1363         |
# |    iterations           | 49           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 50176        |
# | train/                  |              |
# |    approx_kl            | 3.902515e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | -0.00304     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.01e+03     |
# |    n_updates            | 192          |
# |    policy_gradient_loss | -0.000348    |
# |    value_loss           | 2.12e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 104           |
# |    ep_rew_mean          | -113          |
# | time/                   |               |
# |    fps                  | 1364          |
# |    iterations           | 50            |
# |    time_elapsed         | 37            |
# |    total_timesteps      | 51200         |
# | train/                  |               |
# |    approx_kl            | 0.00015201623 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.36         |
# |    explained_variance   | -0.00412      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 670           |
# |    n_updates            | 196           |
# |    policy_gradient_loss | -0.000862     |
# |    value_loss           | 1.27e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 105           |
# |    ep_rew_mean          | -115          |
# | time/                   |               |
# |    fps                  | 1364          |
# |    iterations           | 51            |
# |    time_elapsed         | 38            |
# |    total_timesteps      | 52224         |
# | train/                  |               |
# |    approx_kl            | 0.00023104833 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.36         |
# |    explained_variance   | -0.00429      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 638           |
# |    n_updates            | 200           |
# |    policy_gradient_loss | -0.000481     |
# |    value_loss           | 1.3e+03       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 105           |
# |    ep_rew_mean          | -117          |
# | time/                   |               |
# |    fps                  | 1365          |
# |    iterations           | 52            |
# |    time_elapsed         | 38            |
# |    total_timesteps      | 53248         |
# | train/                  |               |
# |    approx_kl            | 0.00025285798 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.36         |
# |    explained_variance   | -0.00251      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 647           |
# |    n_updates            | 204           |
# |    policy_gradient_loss | -0.000996     |
# |    value_loss           | 1.28e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 104           |
# |    ep_rew_mean          | -117          |
# | time/                   |               |
# |    fps                  | 1366          |
# |    iterations           | 53            |
# |    time_elapsed         | 39            |
# |    total_timesteps      | 54272         |
# | train/                  |               |
# |    approx_kl            | 0.00020524755 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.35         |
# |    explained_variance   | -0.00709      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.64e+03      |
# |    n_updates            | 208           |
# |    policy_gradient_loss | -0.00049      |
# |    value_loss           | 3.32e+03      |
# ...
# |    fps                  | 823          |
# |    iterations           | 960          |
# |    time_elapsed         | 1193         |
# |    total_timesteps      | 983040       |
# | train/                  |              |
# |    approx_kl            | 0.0018374503 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.501        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 348          |
# |    n_updates            | 3836         |
# |    policy_gradient_loss | 0.000229     |
# |    value_loss           | 551          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 767          |
# |    ep_rew_mean          | 81.1         |
# | time/                   |              |
# |    fps                  | 823          |
# |    iterations           | 961          |
# |    time_elapsed         | 1194         |
# |    total_timesteps      | 984064       |
# | train/                  |              |
# |    approx_kl            | 0.0012401119 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.891       |
# |    explained_variance   | 0.901        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.8         |
# |    n_updates            | 3840         |
# |    policy_gradient_loss | -0.000703    |
# |    value_loss           | 37.5         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 767           |
# |    ep_rew_mean          | 81            |
# | time/                   |               |
# |    fps                  | 823           |
# |    iterations           | 962           |
# |    time_elapsed         | 1196          |
# |    total_timesteps      | 985088        |
# | train/                  |               |
# |    approx_kl            | 0.00037225976 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.783        |
# |    explained_variance   | 0.655         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 139           |
# |    n_updates            | 3844          |
# |    policy_gradient_loss | -0.000442     |
# |    value_loss           | 254           |
# -------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 767        |
# |    ep_rew_mean          | 80.6       |
# | time/                   |            |
# |    fps                  | 823        |
# |    iterations           | 963        |
# |    time_elapsed         | 1197       |
# |    total_timesteps      | 986112     |
# | train/                  |            |
# |    approx_kl            | 0.00675267 |
# |    clip_fraction        | 0.0266     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.05      |
# |    explained_variance   | 0.953      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.89       |
# |    n_updates            | 3848       |
# |    policy_gradient_loss | -0.000898  |
# |    value_loss           | 21.2       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 755          |
# |    ep_rew_mean          | 80.3         |
# | time/                   |              |
# |    fps                  | 823          |
# |    iterations           | 964          |
# |    time_elapsed         | 1198         |
# |    total_timesteps      | 987136       |
# | train/                  |              |
# |    approx_kl            | 0.0036772836 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.949        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.8         |
# |    n_updates            | 3852         |
# |    policy_gradient_loss | -0.00191     |
# |    value_loss           | 23.5         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 755           |
# |    ep_rew_mean          | 80.3          |
# | time/                   |               |
# |    fps                  | 823           |
# |    iterations           | 965           |
# |    time_elapsed         | 1199          |
# |    total_timesteps      | 988160        |
# | train/                  |               |
# |    approx_kl            | 0.00022285082 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.863        |
# |    explained_variance   | 0.507         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 286           |
# |    n_updates            | 3856          |
# |    policy_gradient_loss | 0.000112      |
# |    value_loss           | 777           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 755          |
# |    ep_rew_mean          | 80.2         |
# | time/                   |              |
# |    fps                  | 823          |
# |    iterations           | 966          |
# |    time_elapsed         | 1201         |
# |    total_timesteps      | 989184       |
# | train/                  |              |
# |    approx_kl            | 0.0063227145 |
# |    clip_fraction        | 0.0286       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.973        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.98         |
# |    n_updates            | 3860         |
# |    policy_gradient_loss | -0.00143     |
# |    value_loss           | 14.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 755         |
# |    ep_rew_mean          | 80.8        |
# | time/                   |             |
# |    fps                  | 823         |
# |    iterations           | 967         |
# |    time_elapsed         | 1202        |
# |    total_timesteps      | 990208      |
# | train/                  |             |
# |    approx_kl            | 0.002304484 |
# |    clip_fraction        | 0.00977     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.892      |
# |    explained_variance   | 0.963       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.89        |
# |    n_updates            | 3864        |
# |    policy_gradient_loss | -0.000976   |
# |    value_loss           | 16.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 755          |
# |    ep_rew_mean          | 81.2         |
# | time/                   |              |
# |    fps                  | 823          |
# |    iterations           | 968          |
# |    time_elapsed         | 1204         |
# |    total_timesteps      | 991232       |
# | train/                  |              |
# |    approx_kl            | 0.0019870894 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.644        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 217          |
# |    n_updates            | 3868         |
# |    policy_gradient_loss | -0.000642    |
# |    value_loss           | 392          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 757         |
# |    ep_rew_mean          | 81.1        |
# | time/                   |             |
# |    fps                  | 823         |
# |    iterations           | 969         |
# |    time_elapsed         | 1205        |
# |    total_timesteps      | 992256      |
# | train/                  |             |
# |    approx_kl            | 0.002943565 |
# |    clip_fraction        | 0.0112      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.641      |
# |    explained_variance   | 0.961       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.19        |
# |    n_updates            | 3872        |
# |    policy_gradient_loss | -0.00453    |
# |    value_loss           | 20.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 755          |
# |    ep_rew_mean          | 78.9         |
# | time/                   |              |
# |    fps                  | 823          |
# |    iterations           | 970          |
# |    time_elapsed         | 1206         |
# |    total_timesteps      | 993280       |
# | train/                  |              |
# |    approx_kl            | 0.0012403658 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.775       |
# |    explained_variance   | 0.657        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 81.8         |
# |    n_updates            | 3876         |
# |    policy_gradient_loss | -0.000928    |
# |    value_loss           | 234          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 755          |
# |    ep_rew_mean          | 79.1         |
# | time/                   |              |
# |    fps                  | 822          |
# |    iterations           | 971          |
# |    time_elapsed         | 1208         |
# |    total_timesteps      | 994304       |
# | train/                  |              |
# |    approx_kl            | 0.0007448189 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.939       |
# |    explained_variance   | 0.697        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 176          |
# |    n_updates            | 3880         |
# |    policy_gradient_loss | -0.00149     |
# |    value_loss           | 397          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 755          |
# |    ep_rew_mean          | 79.7         |
# | time/                   |              |
# |    fps                  | 822          |
# |    iterations           | 972          |
# |    time_elapsed         | 1209         |
# |    total_timesteps      | 995328       |
# | train/                  |              |
# |    approx_kl            | 0.0009514751 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.964       |
# |    explained_variance   | 0.96         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.59         |
# |    n_updates            | 3884         |
# |    policy_gradient_loss | -0.000715    |
# |    value_loss           | 21.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 755         |
# |    ep_rew_mean          | 80.1        |
# | time/                   |             |
# |    fps                  | 822         |
# |    iterations           | 973         |
# |    time_elapsed         | 1211        |
# |    total_timesteps      | 996352      |
# | train/                  |             |
# |    approx_kl            | 0.008650694 |
# |    clip_fraction        | 0.0247      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | 0.957       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.6        |
# |    n_updates            | 3888        |
# |    policy_gradient_loss | -0.00125    |
# |    value_loss           | 28.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 754          |
# |    ep_rew_mean          | 82.6         |
# | time/                   |              |
# |    fps                  | 822          |
# |    iterations           | 974          |
# |    time_elapsed         | 1212         |
# |    total_timesteps      | 997376       |
# | train/                  |              |
# |    approx_kl            | 0.0026646215 |
# |    clip_fraction        | 0.00903      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.992       |
# |    explained_variance   | 0.932        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 25           |
# |    n_updates            | 3892         |
# |    policy_gradient_loss | -0.00255     |
# |    value_loss           | 43.7         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 754           |
# |    ep_rew_mean          | 83.5          |
# | time/                   |               |
# |    fps                  | 822           |
# |    iterations           | 975           |
# |    time_elapsed         | 1214          |
# |    total_timesteps      | 998400        |
# | train/                  |               |
# |    approx_kl            | 0.00085981924 |
# |    clip_fraction        | 0.00195       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.956        |
# |    explained_variance   | 0.785         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 111           |
# |    n_updates            | 3896          |
# |    policy_gradient_loss | -0.00152      |
# |    value_loss           | 231           |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 749         |
# |    ep_rew_mean          | 84.6        |
# | time/                   |             |
# |    fps                  | 822         |
# |    iterations           | 976         |
# |    time_elapsed         | 1215        |
# |    total_timesteps      | 999424      |
# | train/                  |             |
# |    approx_kl            | 0.000738308 |
# |    clip_fraction        | 0.000732    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.837      |
# |    explained_variance   | 0.966       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13          |
# |    n_updates            | 3900        |
# |    policy_gradient_loss | -0.000265   |
# |    value_loss           | 31.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 745          |
# |    ep_rew_mean          | 85.5         |
# | time/                   |              |
# |    fps                  | 822          |
# |    iterations           | 977          |
# |    time_elapsed         | 1216         |
# |    total_timesteps      | 1000448      |
# | train/                  |              |
# |    approx_kl            | 0.0015231972 |
# |    clip_fraction        | 0.000732     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.87        |
# |    explained_variance   | 0.683        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 112          |
# |    n_updates            | 3904         |
# |    policy_gradient_loss | -0.00183     |
# |    value_loss           | 267          |
# ------------------------------------------

# %%
eval_env = gym.make("LunarLander-v2")
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic=True)
print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
# Out:
# /home/mengel/dev/hugging_face_deep_reinforcement/.venv/lib/python3.8/site-packages/stable_baselines3/common/evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# mean_reward=71.22 +/- 120.87691176050544

# %%
# Publish to hugging face
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
import gym

from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.env_util import make_vec_env

from huggingface_sb3 import package_to_hub

# PLACE the variables you've just defined two cells above
# Define the name of the environment
env_id = "LunarLander-v2"

# TODO: Define the model architecture we used
model_architecture = "PPO"

## Define a repo_id
## repo_id is the id of the model repository from the Hugging Face Hub (repo_id = {organization}/{repo_name} for instance ThomasSimonini/ppo-LunarLander-v2
## CHANGE WITH YOUR REPO ID
repo_id = "Infaninio/ppo-LunarLander-v2"

## Define the commit message
commit_message = "Upload PPO LunarLander-v2 trained agent"

# Create the evaluation env
eval_env = DummyVecEnv([lambda: gym.make(env_id)])

# PLACE the package_to_hub function you've just filled here
package_to_hub(model=model, # Our trained model
               model_name=model_name, # The name of our trained model 
               model_architecture=model_architecture, # The model architecture we used: in our case PPO
               env_id=env_id, # Name of the environment
               eval_env=eval_env, # Evaluation Environment
               repo_id=repo_id, # id of the model repository from the Hugging Face Hub (repo_id = {organization}/{repo_name} for instance ThomasSimonini/ppo-LunarLander-v2
               commit_message=commit_message)
# Out:
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to 1min.
# This is a work in progress: if you encounter a bug, please open an issue.
# Saving video to /tmp/tmpdezrewmn/-step-0-to-step-1000.mp4
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/tmp/tmpdezrewmn/-step-0-to-step-1000.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:20.02, start: 0.000000, bitrate: 112 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 600x400, 107 kb/s, 50 fps, 50 tbr, 12800 tbn, 100 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x558dae94f980] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x558dae94f980] profile High, level 3.1
# [libx264 @ 0x558dae94f980] 264 - core 155 r2917 0a84d98 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/tmp/tmpj9nxk2pl/replay.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 600x400, q=-1--1, 50 fps, 12800 tbn, 50 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame= 1001 fps=0.0 q=-1.0 Lsize=     263kB time=00:00:19.96 bitrate= 107.8kbits/s speed=50.5x
# video:250kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 4.988372%
# [libx264 @ 0x558dae94f980] frame I:5     Avg QP:10.10  size:  1958
# [libx264 @ 0x558dae94f980] frame P:256   Avg QP:24.25  size:   320
# [libx264 @ 0x558dae94f980] frame B:740   Avg QP:27.11  size:   222
# [libx264 @ 0x558dae94f980] consecutive B-frames:  0.7%  1.4%  2.4% 95.5%
# [libx264 @ 0x558dae94f980] mb I  I16..4: 76.3% 17.5%  6.2%
# [libx264 @ 0x558dae94f980] mb P  I16..4:  0.2%  0.6%  0.4%  P16..4:  1.8%  0.6%  0.2%  0.0%  0.0%    skip:96.2%
# [libx264 @ 0x558dae94f980] mb B  I16..4:  0.1%  0.1%  0.3%  B16..8:  3.6%  0.4%  0.1%  direct: 0.1%  skip:95.4%  L0:54.7% L1:44.2% BI: 1.1%
# [libx264 @ 0x558dae94f980] 8x8 transform intra:25.7% inter:11.2%
# [libx264 @ 0x558dae94f980] coded y,uvDC,uvAC intra: 13.5% 25.9% 25.0% inter: 0.3% 0.3% 0.3%
# [libx264 @ 0x558dae94f980] i16 v,h,dc,p: 77% 18%  5%  0%
# [libx264 @ 0x558dae94f980] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 21% 13% 66%  0%  0%  0%  0%  0%  0%
# [libx264 @ 0x558dae94f980] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 12% 11% 64%  2%  3%  3%  2%  2%  2%
# [libx264 @ 0x558dae94f980] i8c dc,h,v,p: 88%  7%  5%  0%
# [libx264 @ 0x558dae94f980] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x558dae94f980] ref P L0: 56.4%  1.9% 27.3% 14.4%
# [libx264 @ 0x558dae94f980] ref B L0: 68.2% 27.4%  4.4%
# [libx264 @ 0x558dae94f980] ref B L1: 90.9%  9.1%
# [libx264 @ 0x558dae94f980] kb/s:102.13
# ℹ Pushing repo Infaninio/ppo-LunarLander-v2 to the Hugging Face Hub
# ℹ Your model is pushed to the Hub. You can view your model here:
# https://huggingface.co/Infaninio/ppo-LunarLander-v2/tree/main/
# 'https://huggingface.co/Infaninio/ppo-LunarLander-v2/tree/main/'
